# %%
import numpy as np
import pandas as pd

# %%
first_array = np.random.rand(5,5)
first_array = first_array*25

# %%
first_array
# Out:
# array([[ 4.75066924, 10.94609538, 10.74359663, 19.45759596,  3.12156407],
#        [ 4.98090283,  5.60420409,  0.47373571,  0.97574822, 17.6113699 ],
#        [22.86087696, 23.25429465, 13.79731223, 23.12068597, 13.14814694],
#        [ 4.61688765, 13.78332798,  0.53384022,  0.16390122,  7.00945007],
#        [ 5.30577299,  9.61987373, 10.83163427, 18.53529051, 22.03063167]])

# %%
#1
np.sum(first_array > 12)
# Out:
# 10

# %%
#2
np.sum(first_array < 10)
# Out:
# 12

# %%
#3
first_array = first_array + 5

# %%
first_array
# Out:
# array([[ 9.75066924, 15.94609538, 15.74359663, 24.45759596,  8.12156407],
#        [ 9.98090283, 10.60420409,  5.47373571,  5.97574822, 22.6113699 ],
#        [27.86087696, 28.25429465, 18.79731223, 28.12068597, 18.14814694],
#        [ 9.61688765, 18.78332798,  5.53384022,  5.16390122, 12.00945007],
#        [10.30577299, 14.61987373, 15.83163427, 23.53529051, 27.03063167]])

# %%
#4
first_array = first_array - 2

# %%
#5
first_array = first_array * 5

# %%
#6
first_array = first_array / 3

# %%
first_array
# Out:
# array([[12.91778207, 23.24349231, 22.90599438, 37.42932661, 10.20260678],
#        [13.30150471, 14.34034015,  5.78955952,  6.62624703, 34.35228317],
#        [43.1014616 , 43.75715776, 27.99552038, 43.53447661, 26.91357824],
#        [12.69481274, 27.97221329,  5.8897337 ,  5.27316871, 16.68241678],
#        [13.84295498, 21.03312289, 23.05272378, 35.89215086, 41.71771945]])

# %%
##Manipulation
#1
first_array[2,1:]
# Out:
# array([43.75715776, 27.99552038, 43.53447661, 26.91357824])

# %%
#2
first_array[2:,3]
# Out:
# array([43.53447661,  5.27316871, 35.89215086])

# %%
#3
first_array[1:4,2:6]
# Out:
# array([[ 5.78955952,  6.62624703, 34.35228317],
#        [27.99552038, 43.53447661, 26.91357824],
#        [ 5.8897337 ,  5.27316871, 16.68241678]])

# %%
##Stats
#1
min(first_array[:,2])
# Out:
# 5.789559519924399

# %%
#2
np.mean(first_array[1,:])
# Out:
# 14.881986915859187

# %%
#3
np.median(first_array[4,:])
# Out:
# 23.052723777728655

# %%
#4
np.std(first_array[3,2:])
# Out:
# 5.239095572716552

# %%
##Pandas
import sqlite3

# %%
soc = sqlite3.connect('database.sqlite')

# %%
##Player Tables
#1
player_data = pd.read_sql_query("SELECT * FROM Player",soc)
player_data
# Out:
#           id  player_api_id          player_name  player_fifa_api_id  \
# 0          1         505942   Aaron Appindangoye              218353
# 1          2         155782      Aaron Cresswell              189615
# 2          3         162549          Aaron Doran              186170
# 3          4          30572        Aaron Galindo              140161
# 4          5          23780         Aaron Hughes               17725
# ...      ...            ...                  ...                 ...
# 11055  11071          26357       Zoumana Camara                2488
# 11056  11072         111182         Zsolt Laczko              164680
# 11057  11073          36491            Zsolt Low              111191
# 11058  11074          35506  Zurab Khizanishvili               47058
# 11059  11075          39902   Zvjezdan Misimovic              102359
#
#                   birthday  height  weight
# 0      1992-02-29 00:00:00  182.88     187
# 1      1989-12-15 00:00:00  170.18     146
# ...

# %%
#2
cursor = soc.cursor()
cursor.execute("select sql from sqlite_master where sql not NULL")
for row in cursor.fetchall():
    print(row[0])
# Out:
# CREATE TABLE sqlite_sequence(name,seq)
# CREATE TABLE "Player_Attributes" (
# 	`id`	INTEGER PRIMARY KEY AUTOINCREMENT,
# 	`player_fifa_api_id`	INTEGER,
# 	`player_api_id`	INTEGER,
# 	`date`	TEXT,
# 	`overall_rating`	INTEGER,
# 	`potential`	INTEGER,
# 	`preferred_foot`	TEXT,
# 	`attacking_work_rate`	TEXT,
# 	`defensive_work_rate`	TEXT,
# 	`crossing`	INTEGER,
# 	`finishing`	INTEGER,
# 	`heading_accuracy`	INTEGER,
# 	`short_passing`	INTEGER,
# 	`volleys`	INTEGER,
# 	`dribbling`	INTEGER,
# 	`curve`	INTEGER,
# 	`free_kick_accuracy`	INTEGER,
# 	`long_passing`	INTEGER,
# 	`ball_control`	INTEGER,
# 	`acceleration`	INTEGER,
# 	`sprint_speed`	INTEGER,
# 	`agility`	INTEGER,
# 	`reactions`	INTEGER,
# 	`balance`	INTEGER,
# 	`shot_power`	INTEGER,
# 	`jumping`	INTEGER,
# 	`stamina`	INTEGER,
# 	`strength`	INTEGER,
# 	`long_shots`	INTEGER,
# 	`aggression`	INTEGER,
# 	`interceptions`	INTEGER,
# 	`positioning`	INTEGER,
# 	`vision`	INTEGER,
# 	`penalties`	INTEGER,
# 	`marking`	INTEGER,
# ...

# %%
#3
player_data.boxplot(column=["height","weight"])

# %%
player_data.hist(column=["height","weight"])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F68C866B20>,
# ...
#       dtype=object)

# %%
#Player attributes
#1
player_att = pd.read_sql_query("SELECT * FROM Player_Attributes LIMIT 10",soc)
player_att
# Out:
#    id  player_fifa_api_id  player_api_id                 date  overall_rating  \
# 0   1              218353         505942  2016-02-18 00:00:00              67
# 1   2              218353         505942  2015-11-19 00:00:00              67
# 2   3              218353         505942  2015-09-21 00:00:00              62
# 3   4              218353         505942  2015-03-20 00:00:00              61
# 4   5              218353         505942  2007-02-22 00:00:00              61
# 5   6              189615         155782  2016-04-21 00:00:00              74
# 6   7              189615         155782  2016-04-07 00:00:00              74
# 7   8              189615         155782  2016-01-07 00:00:00              73
# 8   9              189615         155782  2015-12-24 00:00:00              73
# 9  10              189615         155782  2015-12-17 00:00:00              73
#
#    potential preferred_foot attacking_work_rate defensive_work_rate  crossing  \
# ...

# %%
#2
cursor = soc.cursor()
cursor.execute("select sql from sqlite_master where sql not NULL")
for row in cursor.fetchall():
    print(row[0])
# Out:
# CREATE TABLE sqlite_sequence(name,seq)
# CREATE TABLE "Player_Attributes" (
# 	`id`	INTEGER PRIMARY KEY AUTOINCREMENT,
# 	`player_fifa_api_id`	INTEGER,
# 	`player_api_id`	INTEGER,
# 	`date`	TEXT,
# 	`overall_rating`	INTEGER,
# 	`potential`	INTEGER,
# 	`preferred_foot`	TEXT,
# 	`attacking_work_rate`	TEXT,
# 	`defensive_work_rate`	TEXT,
# 	`crossing`	INTEGER,
# 	`finishing`	INTEGER,
# 	`heading_accuracy`	INTEGER,
# 	`short_passing`	INTEGER,
# 	`volleys`	INTEGER,
# 	`dribbling`	INTEGER,
# 	`curve`	INTEGER,
# 	`free_kick_accuracy`	INTEGER,
# 	`long_passing`	INTEGER,
# 	`ball_control`	INTEGER,
# 	`acceleration`	INTEGER,
# 	`sprint_speed`	INTEGER,
# 	`agility`	INTEGER,
# 	`reactions`	INTEGER,
# 	`balance`	INTEGER,
# 	`shot_power`	INTEGER,
# 	`jumping`	INTEGER,
# 	`stamina`	INTEGER,
# 	`strength`	INTEGER,
# 	`long_shots`	INTEGER,
# 	`aggression`	INTEGER,
# 	`interceptions`	INTEGER,
# 	`positioning`	INTEGER,
# 	`vision`	INTEGER,
# 	`penalties`	INTEGER,
# 	`marking`	INTEGER,
# ...

# %%
#3
player_att_all = pd.read_sql_query("SELECT * FROM Player_Attributes",soc)
player_att_all.hist(column=["penalties"])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F68CA9EC40>]],
#       dtype=object)

# %%
#4
player_att_all.groupby("player_api_id").std().hist(column=["free_kick_accuracy"])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F68CC9A5E0>]],
#       dtype=object)

# %%
#np.max(player_att_all.groupby('player_api_id').std()["free_kick_accuracy"])
# Out:
# 45.254833995939045

# %%
##Team
#1
team_data = pd.read_sql_query("SELECT * FROM Team LIMIT 5",soc)
team_data
# Out:
#    id  team_api_id  team_fifa_api_id     team_long_name team_short_name
# 0   1         9987               673           KRC Genk             GEN
# 1   2         9993               675       Beerschot AC             BAC
# 2   3        10000             15005   SV Zulte-Waregem             ZUL
# 3   4         9994              2007   Sporting Lokeren             LOK
# 4   5         9984              1750  KSV Cercle Brugge             CEB

# %%
#2
cursor = soc.cursor()
cursor.execute("select sql from sqlite_master where sql not NULL")
for row in cursor.fetchall():
    print(row[0])
# Out:
# CREATE TABLE sqlite_sequence(name,seq)
# CREATE TABLE "Player_Attributes" (
# 	`id`	INTEGER PRIMARY KEY AUTOINCREMENT,
# 	`player_fifa_api_id`	INTEGER,
# 	`player_api_id`	INTEGER,
# 	`date`	TEXT,
# 	`overall_rating`	INTEGER,
# 	`potential`	INTEGER,
# 	`preferred_foot`	TEXT,
# 	`attacking_work_rate`	TEXT,
# 	`defensive_work_rate`	TEXT,
# 	`crossing`	INTEGER,
# 	`finishing`	INTEGER,
# 	`heading_accuracy`	INTEGER,
# 	`short_passing`	INTEGER,
# 	`volleys`	INTEGER,
# 	`dribbling`	INTEGER,
# 	`curve`	INTEGER,
# 	`free_kick_accuracy`	INTEGER,
# 	`long_passing`	INTEGER,
# 	`ball_control`	INTEGER,
# 	`acceleration`	INTEGER,
# 	`sprint_speed`	INTEGER,
# 	`agility`	INTEGER,
# 	`reactions`	INTEGER,
# 	`balance`	INTEGER,
# 	`shot_power`	INTEGER,
# 	`jumping`	INTEGER,
# 	`stamina`	INTEGER,
# 	`strength`	INTEGER,
# 	`long_shots`	INTEGER,
# 	`aggression`	INTEGER,
# 	`interceptions`	INTEGER,
# 	`positioning`	INTEGER,
# 	`vision`	INTEGER,
# 	`penalties`	INTEGER,
# 	`marking`	INTEGER,
# ...

# %%
#3
team_data_all = pd.read_sql_query("SELECT * FROM Team",soc)
team_data_all["team_fifa_api_id"].fillna(0,inplace=True)
team_data_all["team_api_id"].fillna(0,inplace=True)
#sum(team_data_all["team_fifa_api_id"].isnull())
# Out:
# 0

# %%
##Team Attributes
#1
team_att = pd.read_sql_query("SELECT * FROM Team_Attributes LIMIT 10",soc)
team_att
# Out:
#    id  team_fifa_api_id  team_api_id                 date  buildUpPlaySpeed  \
# 0   1               434         9930  2010-02-22 00:00:00                60
# 1   2               434         9930  2014-09-19 00:00:00                52
# 2   3               434         9930  2015-09-10 00:00:00                47
# 3   4                77         8485  2010-02-22 00:00:00                70
# 4   5                77         8485  2011-02-22 00:00:00                47
# 5   6                77         8485  2012-02-22 00:00:00                58
# 6   7                77         8485  2013-09-20 00:00:00                62
# 7   8                77         8485  2014-09-19 00:00:00                58
# 8   9                77         8485  2015-09-10 00:00:00                59
# 9  10               614         8576  2010-02-22 00:00:00                60
#
#   buildUpPlaySpeedClass  buildUpPlayDribbling buildUpPlayDribblingClass  \
# ...

# %%
#2
cursor = soc.cursor()
cursor.execute("select sql from sqlite_master where sql not NULL")
for row in cursor.fetchall():
    print(row[0])
# Out:
# CREATE TABLE sqlite_sequence(name,seq)
# CREATE TABLE "Player_Attributes" (
# 	`id`	INTEGER PRIMARY KEY AUTOINCREMENT,
# 	`player_fifa_api_id`	INTEGER,
# 	`player_api_id`	INTEGER,
# 	`date`	TEXT,
# 	`overall_rating`	INTEGER,
# 	`potential`	INTEGER,
# 	`preferred_foot`	TEXT,
# 	`attacking_work_rate`	TEXT,
# 	`defensive_work_rate`	TEXT,
# 	`crossing`	INTEGER,
# 	`finishing`	INTEGER,
# 	`heading_accuracy`	INTEGER,
# 	`short_passing`	INTEGER,
# 	`volleys`	INTEGER,
# 	`dribbling`	INTEGER,
# 	`curve`	INTEGER,
# 	`free_kick_accuracy`	INTEGER,
# 	`long_passing`	INTEGER,
# 	`ball_control`	INTEGER,
# 	`acceleration`	INTEGER,
# 	`sprint_speed`	INTEGER,
# 	`agility`	INTEGER,
# 	`reactions`	INTEGER,
# 	`balance`	INTEGER,
# 	`shot_power`	INTEGER,
# 	`jumping`	INTEGER,
# 	`stamina`	INTEGER,
# 	`strength`	INTEGER,
# 	`long_shots`	INTEGER,
# 	`aggression`	INTEGER,
# 	`interceptions`	INTEGER,
# 	`positioning`	INTEGER,
# 	`vision`	INTEGER,
# 	`penalties`	INTEGER,
# 	`marking`	INTEGER,
# ...

# %%
#3
team_att_all = pd.read_sql_query("SELECT * FROM Team_Attributes",soc)
team_att_all["buildUpPlaySpeedClass"].hist()

# %%
#4
team_att_all.groupby("team_api_id").mean().hist(column=["defenceAggression"])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F69D282FA0>]],
#       dtype=object)
